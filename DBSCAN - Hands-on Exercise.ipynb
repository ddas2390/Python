# %% [markdown]
# ##  DBSCAN
#
# In this exercise, the mall customers dataset is used to develop a hierarchical clustering model to group similar customers together. Further, we will also plot the dendrogram to help us choose the optimal value of the clusters. Plot the clusters after training the DBSCAN model with the optimal hyperparameters.
#
# First, we will import all the relevant packages.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn import metrics
import scipy.cluster.hierarchy as sch
from sklearn.cluster import DBSCAN 
from sklearn import preprocessing

# %% [markdown]
# Next, let us load the mall customers dataset in a dataframe. This dataset has 5 columns:
# CustomerID - Unique ID assigned to the customer
# Gender - Gender of the Customer
# Age - Age of the Customer
# Annual Income (k$) - Annual Income of the customer
# Spending Score(1-100) - Score assigned by the mall based on customer behavior and spending nature
#
# Using this dataset, the idea is to cluster similar customers together in a group.

# %%
mall_dataset = pd.read_csv('Mall_Customers.csv')
mall_dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
import sweetviz as sv
report = sv.analyze(mall_dataset).show_notebook()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# Looking at the dataset, we can see that there are no missing values. Female customers are more than male customers. Further, the spread of annual income is high from $15K to $137K.
#
# First, let us convert the Gender column to binary encoding.

# %%
label_encoder = preprocessing.LabelEncoder() 

mall_dataset['Gender'] = label_encoder.fit_transform(mall_dataset['Gender'])
mall_dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %% [markdown]
# To train the DBSCAN model, we need to find the optimal value of epsilon and min samples. Let us create a range of epsilon values and min sample size values to be tested.

# %%
from itertools import product

eps_values = np.arange(8,12.75,0.25) # eps values to be investigated
min_samples = np.arange(3,10) # min_samples values to be investigated

## create all the combinations of eps_values and min_samples
DBSCAN_params = list(product(eps_values, min_samples))

# %% [markdown]
# ### Calculate the Silhouette score for all the combinations of epsilon and min samples using DBSCAN and find the best parameters.

# %%
from sklearn.metrics import silhouette_score

sil_score = []
X = mall_dataset.drop(['CustomerID'], axis=1)

for p in DBSCAN_params:
    DBS_clustering = DBSCAN(eps=p[0], min_samples=p[1]).fit(X)
    sil_score.append(silhouette_score(X, DBS_clustering.labels_))

## Get the max Silhouette score
max_score = max(sil_score)

## Get the index of max Silhouette score
max_index = sil_score.index(max(sil_score))

## Get the params corresponding to the best score
best_params = DBSCAN_params[max_index]

print(max_score, max_index, best_params)
# Out:
# 0.25541229267169685 127 (12.5, 4)

# %%
# Finally, apply the DBSCAN method using the best parameters and assign clusters to each data point.
DBS_clustering = DBSCAN(eps=best_params[0], min_samples=best_params[1]).fit(X)

# Assign cluster labels to data points
mall_dataset.loc[:,'cluster'] = DBS_clustering.labels_ 

## Check the cluster counts
mall_dataset['cluster'].value_counts().reset_index().sort_values(by=['index'])
# Out:
#    index  cluster
# 3     -1       18
# 0      0      112
# 4      1        8
# 1      2       34
# 2      3       24
# 5      4        4

# %% [markdown]
# Plot the data points with the cluster marking. The DBSCAN method has created a separate cluster with the noise points marked with -1 as the cluster.
# fig = plt.figure(figsize=(12,6))

# %%
colors = ["#0f96c7","#90e0ef", "#023e8a","#ffbd00","#ff5400", "#000"]

for r in range(6):
    
    ## replace cluster number 5 with Noise cluster
    if r==5:
        r=-1
    
    clustered_customer = mall_dataset[mall_dataset["cluster"] == r]
    plt.scatter(clustered_customer["Annual Income (k$)"], clustered_customer["Spending Score (1-100)"], color=colors[r])
    
plt.title("Mall Customers")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.show()

# %% [markdown]
# In this exercise, we have learned to develop a DBSCAN clustering model. Further, we have learned how to find the optimal hyperparameters with the help of the Silhouette Score. We have also plotted the clustered data points after training the DBSCAN algorithm with the optimal hyperparameters.
