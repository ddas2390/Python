# %%
#!pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=63378f66a893b38bd2579728433f1f0f0bfe3c9560c06d141795c5f7a804e5ff
#   Stored in directory: /Users/mymac/Library/Caches/pip/wheels/4c/a4/ce/ad31f7d9f6bfce32741955de12e76e3a6e7181c20321db3c66
# Successfully built pandasql
# ...

# %%
import pandas as pd
import pandasql as psql

# %%
df = pd.read_csv("/Users/mymac/Documents/Data Science Bootcamp/Week 3 - SQL Database/heroes_information.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
psql.sqldf("select * from df", globals())
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %%
psql.sqldf("select * from df where race='Human'", globals())
# Out:
#      Unnamed: 0             name  Gender Eye color   Race        Hair color  \
# 0             0           A-Bomb    Male    yellow  Human           No Hair
# 1             5    Absorbing Man    Male      blue  Human           No Hair
# 2             7     Adam Strange    Male      blue  Human             Blond
# 3             9        Agent Bob    Male     brown  Human             Brown
# 4            14      Alex Mercer    Male         -  Human                 -
# ..          ...              ...     ...       ...    ...               ...
# 203         713     White Canary  Female     brown  Human             Black
# 204         716   Winter Soldier    Male     brown  Human             Brown
# 205         728     Yellowjacket    Male      blue  Human             Blond
# 206         729  Yellowjacket II  Female      blue  Human  Strawberry Blond
# 207         732          Zatanna  Female      blue  Human             Black
#
#      Height      Publisher Skin color Alignment  Weight
# ...
