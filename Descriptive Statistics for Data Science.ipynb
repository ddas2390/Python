# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Initial Analysis Using Python, obtain the dataset in the form of a table and determine the number of records 
# and characteristics included in the dataset.

# %%
data = pd.read_csv(r"/Users/mymac/Documents/Data Science Bootcamp/Week 7 - Stats/descriptive-case study/nutrition_1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             name serving_size  calories  \
# 0             0           0       Cornstarch        100 g       381
# 1             1           1     Nuts, pecans        100 g       691
# 2             2           2    Eggplant, raw        100 g        25
# 3             3           3   Teff, uncooked        100 g       367
# 4             4           4  Sherbet, orange        100 g       144
#
#    total_fat  saturated_fat  cholesterol  sodium  choline  ...      fat  \
# 0        0.1            NaN          0.0     9.0   0.4 mg  ...   0.05 g
# 1       72.0            6.2          0.0     0.0  40.5 mg  ...  71.97 g
# 2        0.2            NaN          0.0     2.0   6.9 mg  ...   0.18 g
# 3        2.4            0.4          0.0    12.0  13.1 mg  ...   2.38 g
# 4        2.0            1.2          1.0    46.0   7.7 mg  ...   2.00 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 0                  0.009                     0.016 g
# ...

# %%
data.shape
# Out:
# (8789, 78)

# %%
for item in list(data.columns):
    print(item)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# name
# serving_size
# calories
# total_fat
# saturated_fat
# cholesterol
# sodium
# choline
# folate
# folic_acid
# niacin
# pantothenic_acid
# riboflavin
# thiamin
# vitamin_a
# vitamin_a_rae
# carotene_alpha
# carotene_beta
# cryptoxanthin_beta
# lutein_zeaxanthin
# lucopene
# vitamin_b12
# vitamin_b6
# vitamin_c
# vitamin_d
# vitamin_e
# tocopherol_alpha
# vitamin_k
# calcium
# copper
# irom
# magnesium
# manganese
# phosphorous
# potassium
# selenium
# zink
# protein
# alanine
# arginine
# aspartic_acid
# cystine
# glutamic_acid
# glycine
# histidine
# hydroxyproline
# isoleucine
# leucine
# lysine
# methionine
# phenylalanine
# proline
# serine
# threonine
# tryptophan
# tyrosine
# valine
# carbohydrate
# fiber
# sugars
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat
# saturated_fatty_acids
# monounsaturated_fatty_acids
# polyunsaturated_fatty_acids
# fatty_acids_total_trans
# alcohol
# ash
# caffeine
# theobromine
# water

# %%
# Measures of Central Tendency: To determine the average amount of nutrients contained in the various 
# types of food products, find the mean, median, and mode of the characteristics in the dataset.
